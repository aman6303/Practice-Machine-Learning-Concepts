# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('covid_toy.csv')
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.gender.value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df.fever.isnull().sum()  # 10 values are missing
# Out:
# np.int64(10)

# %%
df.cough.value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df.city.value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
# now we will be fill fever missing value with mean using simpleimputer class
# apply ordinal encoding on cough
# apply one hot encoding on city and gender

# other columns will be pass as it is.

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
# splitting the dataset
# here i am doing direct

x = df[['age','gender','fever','cough','city']]

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer

# %%
# now applying it 

# creating obj

transformer = ColumnTransformer(transformers=[
    ("tr1",SimpleImputer(),['fever']),
    ("tr2",OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tr3',OneHotEncoder(drop = 'first', sparse_output=False),['gender','city'])
],remainder = 'passthrough')

# %%
transformer.fit(x)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('tr1', SimpleImputer(), ['fever']),
#                                 ('tr2',
#                                  OrdinalEncoder(categories=[['Mild',
#                                                              'Strong']]),
#                                  ['cough']),
#                                 ('tr3',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['gender', 'city'])])

# %%
x_new = transformer.transform(x)

# %%
x_new.shape
# Out:
# (100, 7)
