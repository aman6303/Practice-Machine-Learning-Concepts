# %%
import pandas as pd

# %%
path = r"C:\Users\DELL\Desktop\Programming\CampusX\100 days of Machine Learning (youtube)\03_reading_a_csv_file_using_pandas\terrorismData.csv"
path = path.replace("\\", "/")
print(path)
# Out:
# C:/Users/DELL/Desktop/Programming/CampusX/100 days of Machine Learning (youtube)/03_reading_a_csv_file_using_pandas/terrorismData.csv

# %%
df = pd.read_csv(path)

# %% [markdown]
# # Q1 How big is data?

# %%
df.shape
# Out:
# (181691, 17)

# %% [markdown]
# # Q2 How does data look Like?

# %%
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
df.tail()
# Out:
#         Year  Month  Day      Country            State  \
# 181686  2017     12   31      Somalia  Middle Shebelle
# 181687  2017     12   31        Syria         Lattakia
# 181688  2017     12   31  Philippines      Maguindanao
# 181689  2017     12   31        India          Manipur
# 181690  2017     12   31  Philippines      Maguindanao
#
#                             Region           City   Latitude   Longitude  \
# 181686          Sub-Saharan Africa  Ceelka Geelow   2.359673   45.385034
# 181687  Middle East & North Africa         Jableh  35.407278   35.942679
# 181688              Southeast Asia       Kubentog   6.900742  124.437908
# 181689                  South Asia         Imphal  24.798346   93.940430
# 181690              Southeast Asia  Cotabato City   7.209594  124.241966
#
#                             AttackType  Killed  Wounded            Target  \
# 181686                   Armed Assault     1.0      2.0        Checkpoint
# ...

# %%
# randomly pick 5 samples
df.sample(5)
# Out:
#         Year  Month  Day  Country           State                      Region  \
# 165020  2016      7   22     Iraq        Al Anbar  Middle East & North Africa
# 4368    1976     12    8    Italy           Lazio              Western Europe
# 17803   1983      1    8    Spain  Basque Country              Western Europe
# 103410  2011     10   11  Germany          Berlin              Western Europe
# 155281  2015     11   10     Iraq          Diyala  Middle East & North Africa
#
#                City   Latitude  Longitude         AttackType  Killed  Wounded  \
# 165020   Saqlawiyah  33.397812  43.706276  Bombing/Explosion     0.0      0.0
# 4368           Rome  41.890961  12.490069      Armed Assault     0.0      0.0
# 17803        Bermeo  43.420422  -2.722158      Assassination     2.0      0.0
# 103410       Berlin  52.501530  13.401851  Bombing/Explosion     0.0      0.0
# 155281  Husseiniyah  33.548306  44.415733  Bombing/Explosion     2.0      5.0
#
# ...

# %% [markdown]
# # Q3 What is the data types of columns?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   City         181257 non-null  object
#  7   Latitude     177135 non-null  float64
#  8   Longitude    177134 non-null  float64
#  9   AttackType   181691 non-null  object
#  10  Killed       171378 non-null  float64
#  11  Wounded      165380 non-null  float64
#  12  Target       181055 non-null  object
#  13  Summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Target_type  181691 non-null  object
#  16  Weapon_type  181691 non-null  object
# dtypes: float64(4), int64(3), object(10)
# ...

# %%
# object means str

# we can decrease size by changindg dtype of columns

# %% [markdown]
# # Q4 Are there any missing values?

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# State            421
# Region             0
# City             434
# Latitude        4556
# Longitude       4557
# AttackType         0
# Killed         10313
# Wounded        16311
# Target           636
# Summary        66129
# Group              0
# Target_type        0
# Weapon_type        0
# dtype: int64

# %% [markdown]
# # Q5 how daoes data look mathematically?

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %% [markdown]
# # Q6 are there any duplicate values ?

# %%
df.duplicated().sum()  # return total no of duplicate rows in df
# Out:
# 9504

# %% [markdown]
# # Q7 How is the correlation between columns?

# %%
df.corr()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9056\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                Year     Month       Day  Latitude  Longitude    Killed  \
# Year       1.000000  0.000139  0.018254  0.166933   0.003917  0.015341
# Month      0.000139  1.000000  0.005497 -0.015978  -0.003880  0.003463
# Day        0.018254  0.005497  1.000000  0.003423  -0.002285 -0.003693
# Latitude   0.166933 -0.015978  0.003423  1.000000   0.001463 -0.018124
# Longitude  0.003917 -0.003880 -0.002285  0.001463   1.000000 -0.000562
# Killed     0.015341  0.003463 -0.003693 -0.018124  -0.000562  1.000000
# Wounded    0.015273  0.002938 -0.001268  0.015988   0.000223  0.534375
#
#             Wounded
# Year       0.015273
# Month      0.002938
# Day       -0.001268
# Latitude   0.015988
# ...

# %%
df.corr()['Day']
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9056\271570429.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Day']
# Year         0.018254
# Month        0.005497
# Day          1.000000
# Latitude     0.003423
# Longitude   -0.002285
# Killed      -0.003693
# Wounded     -0.001268
# Name: Day, dtype: float64

# %%
# it calculate carl pearsons coefficient of correlation
