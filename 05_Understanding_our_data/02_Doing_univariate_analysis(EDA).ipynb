# %%
import pandas as pd

# %%
df = pd.read_csv('titanic-Dataset.csv')

# %% [markdown]
# # first ask 7 questions to understand your data

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 735          736         0       3         Williams, Mr. Leslie    male  28.5
# 725          726         0       3          Oreskovic, Mr. Luka    male  20.0
# 691          692         1       3           Karun, Miss. Manca  female   4.0
# 405          406         0       2           Gale, Mr. Shadrach    male  34.0
# 607          608         1       1  Daniel, Mr. Robert Williams    male  27.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 735      0      0   54636  16.1000   NaN        S
# 725      0      0  315094   8.6625   NaN        S
# 691      0      1  349256  13.4167   NaN        C
# 405      1      0   28664  21.0000   NaN        S
# 607      0      0  113804  30.5000   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# cjeckcing for missing value

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# how does data look mathematically

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# are there any dublicate values

df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated().value_counts()
# Out:
# False    891
# dtype: int64

# %%
# checking how rows are correlated

df.corr()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6528\3542700505.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# ...

# %%
# checking hiw survived column is related with others
df.corr()['Survived']
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6528\2734806061.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Survived']
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %% [markdown]
# # Univariate analysis

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [raw]
# Univariate means analysis of each column individaually. It is a part of EDA (Exploratory data analysis)

# %% [markdown]
# ## 1. If column is categorical
#
# ### a. Countplot

# %%
import seaborn as sns
sns.countplot(x=df.Sex)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# countplot using valuecount plot
df.Sex.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## b. Piechart

# %%
df.Sex.value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Sex'>

# %% [markdown]
# # 2. If value is Numerical
#
# ## a. histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df.Age, bins=10)
plt.show()

# %% [markdown]
# ## b. Distplot (data distribution plot)

# %%
sns.distplot(x=df.Age)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6528\1950010530.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df.Age)
# <Axes: ylabel='Density'>

# %%
sns.displot(x=df.Age)

# %% [markdown]
# ## c. box plot --- give five form output

# %%
sns.boxplot(x=df.Age)
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ## d. By calculating some values

# %%
df.Age.max()
# Out:
# 80.0

# %%
df.Age.min()
# Out:
# 0.42

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.Age.std()
# Out:
# 14.526497332334044

# %%
df.Age.var()
# Out:
# 211.0191247463081

# %%
from scipy.stats import zscore
zscore(df.Age)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 886   NaN
# 887   NaN
# 888   NaN
# 889   NaN
# 890   NaN
# Name: Age, Length: 891, dtype: float64
