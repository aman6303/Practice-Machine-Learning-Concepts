# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred = lr.predict(X_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 0.2884710931878175

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 0.12129235313495527

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 0.34827051717731616

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.780730147510384

# %%
# cgpa is explaining the 80% variance of lpa (target)

# %%
# Adjusted R2 score
X_test.shape
# Out:
# (40, 1)

# %%
# Adjusted R2 score

1 - ((1-r2)*(40-1)/(40-1-1))
# Out:
# 0.7749598882343415

# %% [markdown]
# # compairnng effect on r2 score and adjusted r2 score if we add an irrelevent feature

# %%
# compairnng effect on r2 score and adjusted r2 score if we add an irrelevent feature

new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa','random_feature','package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.316534     3.26
# 1  5.12        0.010076     1.98
# 2  7.82        0.553222     3.25
# 3  7.42        0.924993     3.67
# 4  6.94        0.436750     3.57

# %%
plt.scatter(new_df1['random_feature'],new_df1['package'])
plt.xlabel('random_feature')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.7805049886340364

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7686403934250654

# %% [markdown]
# # compairnng effect on r2 score and adjusted r2 score if we add an imp(relevent) feature

# %%
new_df2 = df.copy()

new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq','package']]

# %%
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 139  7.19  1.80     2.40
# 14   7.73  2.42     3.42
# 118  7.40  1.68     2.88
# 195  6.93  2.86     2.46
# 91   6.22  1.44     2.14

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel('iq')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
np.random.randint(-100,100)
# Out:
# 67

# %%
X = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.8004493411648897

# %%
# both adjusted and simple r2 score is increases
